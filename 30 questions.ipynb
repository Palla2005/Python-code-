# %%
# Calculate the area of a rectangle
L=int(input("Enter length:"))
W=int(input("Enter width:"))
area=L*W
print("Area of rectangle:",area)
# Out:
# Enter length: 10
# Enter width: 5
# Area of rectangle: 50

# %%
# Evalute expression
a=5**2+10-3*2
print(a)
# Out:
# 29

# %%
# Take input values
a=int(input("Enter value of a:",))
b=int(input("Enter value of b:",))
# Calculate reminder
reminder=a/b
print("Reminder:",reminder)
# Out:
# Enter value of a: 10
# Enter value of b: 2
# Reminder: 5.0

# %%
# Calculate average the three numbers
n1=int(input("Enter first number"))
n2=int(input("Enter second number"))
n3=int(input("Enter third number"))
avg=(n1+n2+n3)/3
print("average:",avg)
# Out:
# Enter first number 10
# Enter second number 20
# Enter third number 50
# average: 26.666666666666668

# %%
# Calculate perimente input side length
side=int(input("Enter side length of square:"))
perimeter=4*side
print("perimeter of square=",perimeter)
# Out:
# Enter side length of square: 5
# perimeter of square= 20

# %%
# logical equation and check number
n=int(input("Enter a number:"))
result=(n>10)and(n<50)
print(result)
# Out:
# Enter a number: 25
# True

# %%
# Calculate cube a number
n=int(input("Enter a number:",))
cube=n**3
print(cube)
# Out:
# Enter a number: 5
# 125

# %%
# Swap third variable two numbers
a=int(input("Enter first number(a):"))
b=int(input("Enter second number(b):"))
temp=a
a=b
b=temp
print("After swapping:")
print("a=",a)
print("b=",b)
# Out:
# Enter first number(a): 10
# Enter second number(b): 20
# After swapping:
# a= 20
# b= 10

# %%
# Simple interest 
P=int(input("Enter principal ammout:"))
R=int(input("Enter rate of interst:"))
T=int(input("Enter time(in yeat):"))
SI=(P*R*T)/100
print("simple Interst=",SI)
# Out:
# Enter principal ammout: 1000
# Enter rate of interst: 5
# Enter time(in yeat): 2
# simple Interst= 100.0

# %%
# Calculate area of circle
r=int(input("Enter radius of circle:"))
area=3.14*r*r
print("Area of circle=",area)
# Out:
# Enter radius of circle: 5
# Area of circle= 78.5

# %%
# Calculate absolute difference from user
a=int(input("Enter first number:"))
b=int(input("Enter second number:"))
difference=abs(a-b)
print("Absolute difference is:",difference)
# Out:
# Enter first number: 4
# Enter second number: 5
# Absolute difference is: 1

# %%
# convert to fahrenheit celsius from user
celsius=int(input("Enter temperature in celsius:",))
fahrenheir=(celsius*9/5)+32
print(fahrenheir)
# Out:
# Enter temperature in celsius: 25
# 77.0

# %%
# convert to celsius fahrenheir from user
fahrenheit=int(input("Enter temperaturef in fahrenheit:",))
celsius=(fahrenheir-32)*5/9
print(celsius)
# Out:
# Enter temperaturef in fahrenheit: 34
# 25.0

# %%
# Calculate the sum of all elements in a list
numbers=[10,20,30,40,50,]
total=sum(numbers)
print(" Sum of all elements=",total)
# Out:
#  Sum of all elements= 150

# %%
# Merged list
list1=[1,2,3,]
list2=[4,5,6]
merged_list=list1+list2
print("Merged List:",merged_list)
# Out:
# Merged List: [1, 2, 3, 4, 5, 6]

# %%
# 
marks={"Amit":85,"Riya":67,"Prachi":89,"Aditi":70}
highest_student=max(marks,key=marks.get)
print("Highest marks:",marks[highest_student])
print("Student name:",highest_student)
# Out:
# Highest marks: 89
# Student name: Prachi

# %%
# calculate maximum number
number=[10,20,30,40,50] 
maximum=max(number)
print("Maximum element:",maximum)
# Out:
# Maximum element: 50

# %%
# calculate minimum number
number=[10,20,30,40,50] 
minimum=min(number)
print("Minimum element:",minimum)
# Out:
# Minimum element: 10

# %%
# reverse number
num=int(input("Enter a number:"))
reverse=0
while num>0:
    digit=num%1
    reverse=reverse*10+digit
    num=num//10
print("Reverse number:",reverse)
# Out:
# Enter a number: 1234
# Reverse number: 0

# %%
# simple interest
p=10000
r=5
t=2
si=(p*r*t)/100
print("Simple Interest=:",si)
# Out:
# Simple Interest=: 1000.0

# %%
#compound interest
p=20000
r=6
t=3
a=p*(1+r/100)**t
print("Amount=",a)
# Out:
# Amount= 23820.32

# %%
# area of circle
r=7
area=3.14*r*r
print("Area=",area)
# Out:
# Area= 153.86

# %%
# area of tringle
b=10
h=8
area=0.5*b*h
print("Area=",area)
# Out:
# Area= 40.0

# %%
# percentage calculate
obtained=450
total=500
percentage=(obtained/total)*100
print("Percentage=",percentage)
# Out:
# Percentage= 90.0

# %%
# BMI calculation
weight=40
height=1.75
bmi=weight/(height**2)
print("BMI=",bmi)
# Out:
# BMI= 13.061224489795919

# %%
# profit calculation
cp=500
sp=700
profit=sp-cp
print("Profit=",profit)
# Out:
# Profit= 200

# %%
#discount calculation
price=1000
rate=20
discount=price*rate/100
print("Discount=",discount)
# Out:
# Discount= 200.0

# %%
# salary increment calculation(5% increase)
salary=50000
new_salary=salary+salary*5/100
print("New salary=",new_salary)
# Out:
# New salary= 52500.0

# %%
#celcius to fahrenheit conversion
c=25
f=(c*9/5)+32
print("Fahrenheit=",f)
# Out:
# Fahrenheit= 77.0

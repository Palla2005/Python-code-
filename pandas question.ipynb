# %%
import pandas as pd
data=pd.read_excel("Pandas(5).xlsx")
data
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# ...      ...            ...       ...         ...            ...          ...
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
# ...

# %%
#1.Display the first 10 rows using iloc.
data.iloc[0:10]
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   18606  Not Specified      0.01        2.88           0.50            2
# 1   20847           High      0.01        2.84           0.93            3
# 2   23086  Not Specified      0.03        6.68           6.15            3
# 3   23087  Not Specified      0.01        5.68           3.60            3
# 4   23088  Not Specified      0.00      205.99           2.50            3
# 5   23597         Medium      0.09       55.48          14.30            3
# 6   25549            Low      0.08      120.97          26.30            3
# 7   20228  Not Specified      0.02      500.98          26.00            5
# 8   19483            Low      0.08        6.48           6.81            5
# 9   24782           High      0.01       90.24           0.99            6
#
#      Customer Name       Ship Mode Customer Segment Product Category  ...  \
# ...

# %%
#2.display the last 5 rows using iloc.
data.iloc[-5:]
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
#        Customer Name       Ship Mode Customer Segment Product Category  ...  \
# 9421  Frederick Cole     Regular Air         Consumer  Office Supplies  ...
# 9422  Frederick Cole     Regular Air         Consumer  Office Supplies  ...
# 9423  Frederick Cole  Delivery Truck         Consumer        Furniture  ...
# 9424   Tammy Buckley     Express Air         Consumer        Furniture  ...
# 9425   Tammy Buckley     Express Air         Consumer  Office Supplies  ...
#
# ...

# %%
#3.display rows 20 to 30 and all columns.
data.iloc[20:31]
# Out:
#     Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 20   24846         Medium      0.08        3.28           2.31           14
# 21   24847         Medium      0.05        3.28           4.20           14
# 22   24848         Medium      0.05        3.58           1.63           14
# 23   24845         Medium      0.01        6.48           7.86           14
# 24   18181       Critical      0.00        4.42           4.99           15
# 25   20925         Medium      0.01       35.94           6.66           15
# 26   18263         Medium      0.03        1.76           0.70           15
# 27   18554         Medium      0.04        5.98           5.20           15
# 28   22781            Low      0.00        7.59           4.00           15
# 29   23287            Low      0.07        4.13           6.89           15
# 30   26267           High      0.04        2.98           1.58           16
#
# ...

# %%
#4.Display the first 5 rows with only customer Name, Region, and Sales columns using iloc.
# print(data.columns)
# data.loc[:4,['Customer Name', 'Region','sales']]
data.iloc[:5,[6,14,22]]
# Out:
#      Customer Name   Region    Sales
# 0  Janice Fletcher  Central     5.90
# 1    Bonnie Potter     West    13.01
# 2    Bonnie Potter     West    49.92
# 3    Bonnie Potter     West    41.64
# 4    Bonnie Potter     West  1446.67

# %%
# 5. display rows 50 to 60 with columns product category to sales using iloc.
# data.coumns
data.iloc[50:61,10:23]
# Out:
#               Product Sub-Category Product Container  \
# 50                      Appliances         Small Box
# 51                      Appliances         Small Box
# 52  Binders and Binder Accessories         Small Box
# 53          Storage & Organization         Large Box
# 54                          Tables         Jumbo Box
# 55              Chairs & Chairmats        Jumbo Drum
# 56                          Labels         Small Box
# 57              Office Furnishings        Small Pack
# 58                           Paper         Small Box
# 59                           Paper         Small Box
# 60                          Tables         Jumbo Box
#
#                                          Product Name  Product Base Margin  \
# 50  Hoover Commercial Soft Guard Upright Vacuum An...                 0.58
# 51                    Belkin F9M820V08 8 Outlet Surge                 0.56
# 52            Fellowes Twister Kit, Gray/Clear, 3/pkg                 0.40
# ...

# %%
# 6.display every 5th row from the dataset using iloc.
data.iloc[::5]
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 5      23597         Medium      0.09       55.48          14.30            3
# 10     24563       Critical      0.07        6.48           6.60            6
# 15     20877         Medium      0.10      286.85          61.76            9
# 20     24846         Medium      0.08        3.28           2.31           14
# ...      ...            ...       ...         ...            ...          ...
# 9405   21952  Not Specified      0.05       10.91           2.99         3397
# 9410   26073       Critical      0.05       59.78          10.29         3399
# 9415   26043  Not Specified      0.06       30.98           6.50         3400
# 9420   18329           High      0.08      212.60          52.20         3402
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
# ...

# %%
#7.display the last 10 rows and only the last 4 columns using iloc.
data.iloc[-10:,-4:]
# Out:
#            Profit  Quantity ordered new    Sales  Order ID
# 9416     3.312000                     8    67.50     87545
# 9417   606.309900                     8   878.71     87546
# 9418   -15.030000                     1    43.90     87546
# 9419   411.481500                    19   596.35     87549
# 9420  -513.790420                    10  1969.31     87531
# 9421   137.860000                    13   447.87     87532
# 9422   -39.070000                     3    13.23     87532
# 9423 -1225.029097                     4  2215.93     87533
# 9424   349.485000                     5   506.50     87530
# 9425    78.062400                    23   172.48     87533

# %%
#loc
#1.display rows 0 to 10 using loc.
data.loc[0:10]
# Out:
#     Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0    18606  Not Specified      0.01        2.88           0.50            2
# 1    20847           High      0.01        2.84           0.93            3
# 2    23086  Not Specified      0.03        6.68           6.15            3
# 3    23087  Not Specified      0.01        5.68           3.60            3
# 4    23088  Not Specified      0.00      205.99           2.50            3
# 5    23597         Medium      0.09       55.48          14.30            3
# 6    25549            Low      0.08      120.97          26.30            3
# 7    20228  Not Specified      0.02      500.98          26.00            5
# 8    19483            Low      0.08        6.48           6.81            5
# 9    24782           High      0.01       90.24           0.99            6
# 10   24563       Critical      0.07        6.48           6.60            6
#
# ...

# %%
#2.display only the customer name and sales columns using loc.
data.loc[:,["Customer Name","Sales"]]
# Out:
#         Customer Name    Sales
# 0     Janice Fletcher     5.90
# 1       Bonnie Potter    13.01
# 2       Bonnie Potter    49.92
# 3       Bonnie Potter    41.64
# 4       Bonnie Potter  1446.67
# ...               ...      ...
# 9421   Frederick Cole   447.87
# 9422   Frederick Cole    13.23
# 9423   Frederick Cole  2215.93
# 9424    Tammy Buckley   506.50
# 9425    Tammy Buckley   172.48
#
# [9426 rows x 2 columns]

# %%
#3.display rows 100 to 110 with columns.Region,State or Province, and sales.
# data.columns
data.loc[100:110,["Region","State or Province","Sales"]]
# Out:
#       Region State or Province    Sales
# 100     West            Oregon    62.59
# 101  Central          Illinois    17.12
# 102  Central          Illinois    90.80
# 103  Central          Illinois   113.59
# 104     West        Washington    30.96
# 105     West        Washington   299.74
# 106     West        Washington   291.56
# 107     West        Washington   158.27
# 108     West        Washington   647.07
# 109     West        Washington    83.01
# 110     West        Washington  1396.96

# %%
#4.display rows 20 to 30 and all columns using loc.
data.loc[20:30]
# Out:
#     Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 20   24846         Medium      0.08        3.28           2.31           14
# 21   24847         Medium      0.05        3.28           4.20           14
# 22   24848         Medium      0.05        3.58           1.63           14
# 23   24845         Medium      0.01        6.48           7.86           14
# 24   18181       Critical      0.00        4.42           4.99           15
# 25   20925         Medium      0.01       35.94           6.66           15
# 26   18263         Medium      0.03        1.76           0.70           15
# 27   18554         Medium      0.04        5.98           5.20           15
# 28   22781            Low      0.00        7.59           4.00           15
# 29   23287            Low      0.07        4.13           6.89           15
# 30   26267           High      0.04        2.98           1.58           16
#
# ...

# %%
#5.display rows 0 to 5 with columns customer name,city, and profit.
data.loc[0:5],["Customer Name","City","Profit"]
# Out:
# (   Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
#  0   18606  Not Specified      0.01        2.88           0.50            2
#  1   20847           High      0.01        2.84           0.93            3
#  2   23086  Not Specified      0.03        6.68           6.15            3
#  3   23087  Not Specified      0.01        5.68           3.60            3
#  4   23088  Not Specified      0.00      205.99           2.50            3
#  5   23597         Medium      0.09       55.48          14.30            3
#
#       Customer Name    Ship Mode Customer Segment Product Category  ...  \
#  0  Janice Fletcher  Regular Air        Corporate  Office Supplies  ...
#  1    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
#  2    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
#  3    Bonnie Potter  Regular Air        Corporate  Office Supplies  ...
#  4    Bonnie Potter  Express Air        Corporate       Technology  ...
# ...

# %%
#6.Display only the columns from Customer name to sales using loc.
data.loc[:,["Customer Name","Sales"]]
# Out:
#         Customer Name    Sales
# 0     Janice Fletcher     5.90
# 1       Bonnie Potter    13.01
# 2       Bonnie Potter    49.92
# 3       Bonnie Potter    41.64
# 4       Bonnie Potter  1446.67
# ...               ...      ...
# 9421   Frederick Cole   447.87
# 9422   Frederick Cole    13.23
# 9423   Frederick Cole  2215.93
# 9424    Tammy Buckley   506.50
# 9425    Tammy Buckley   172.48
#
# [9426 rows x 2 columns]

# %%
#7.Display the first 15 rows with columns order priority, ship mode, and profit.
data.loc[0:15,["Order Priority","Ship Mode","Profit"]]
# Out:
#    Order Priority       Ship Mode       Profit
# 0   Not Specified     Regular Air     1.320000
# 1            High     Express Air     4.560000
# 2   Not Specified     Express Air   -47.640000
# 3   Not Specified     Regular Air   -30.510000
# 4   Not Specified     Express Air   998.202300
# 5          Medium     Express Air  1388.052300
# 6             Low  Delivery Truck  1001.445300
# 7   Not Specified  Delivery Truck  4390.366500
# 8             Low     Regular Air  -141.260000
# 9            High     Regular Air  1045.467300
# 10       Critical     Regular Air   -13.860000
# 11       Critical     Regular Air    57.580500
# 12       Critical     Regular Air  1176.505200
# 13           High     Regular Air    72.992800
# 14         Medium  Delivery Truck  -158.740000
# 15         Medium  Delivery Truck  -346.615198

# %%
# filtering with masking
#1.display all record where sales>500.
data.loc[data["Sales"]>500]
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 4      23088  Not Specified      0.00      205.99           2.50            3
# 5      23597         Medium      0.09       55.48          14.30            3
# 6      25549            Low      0.08      120.97          26.30            3
# 7      20228  Not Specified      0.02      500.98          26.00            5
# 9      24782           High      0.01       90.24           0.99            6
# ...      ...            ...       ...         ...            ...          ...
# 9417   23413       Critical      0.07      115.79           1.99         3400
# 9419   24912         Medium      0.05       35.99           1.25         3400
# 9420   18329           High      0.08      212.60          52.20         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
#
# ...

# %%
#2.display all products where profit<0.
data.loc[data["Profit"]<0]
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 8      19483            Low      0.08        6.48           6.81            5
# 10     24563       Critical      0.07        6.48           6.60            6
# 14     20876         Medium      0.08      140.98          36.09            8
# ...      ...            ...       ...         ...            ...          ...
# 9415   26043  Not Specified      0.06       30.98           6.50         3400
# 9418   23414       Critical      0.02       37.44           4.27         3400
# 9420   18329           High      0.08      212.60          52.20         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
#
# ...

# %%
#3.display customers from the west region.
data.loc[data["Region"]=="West"]
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# 5      23597         Medium      0.09       55.48          14.30            3
# ...      ...            ...       ...         ...            ...          ...
# 9390   23658         Medium      0.00       12.28           4.86         3394
# 9391   22578  Not Specified      0.04        6.84           8.37         3394
# 9392   22579  Not Specified      0.07      125.99           7.69         3394
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
# ...

# %%
#4.display records where discount>0.05.
data.loc[data["Discount"]>0.05]
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 5      23597         Medium      0.09       55.48          14.30            3
# 6      25549            Low      0.08      120.97          26.30            3
# 8      19483            Low      0.08        6.48           6.81            5
# 10     24563       Critical      0.07        6.48           6.60            6
# 12     24565       Critical      0.10       85.99           0.99            6
# ...      ...            ...       ...         ...            ...          ...
# 9420   18329           High      0.08      212.60          52.20         3402
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
# ...

# %%
#5.display products whose quantity ordered new>10.
data.loc[data["Quantity ordered new"]>10]
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 5      23597         Medium      0.09       55.48          14.30            3
# 6      25549            Low      0.08      120.97          26.30            3
# 7      20228  Not Specified      0.02      500.98          26.00            5
# 8      19483            Low      0.08        6.48           6.81            5
# 9      24782           High      0.01       90.24           0.99            6
# ...      ...            ...       ...         ...            ...          ...
# 9413   24911         Medium      0.10        9.38           4.93         3400
# 9414   26042  Not Specified      0.09        8.46           3.62         3400
# 9419   24912         Medium      0.05       35.99           1.25         3400
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
# ...

# %%
#6.display orders where Shipping Cost>20.
data.loc[data["Shipping Cost"]>20]
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 6      25549            Low      0.08      120.97          26.30            3
# 7      20228  Not Specified      0.02      500.98          26.00            5
# 14     20876         Medium      0.08      140.98          36.09            8
# 15     20877         Medium      0.10      286.85          61.76            9
# 39     20578            Low      0.02      110.98          30.00           18
# ...      ...            ...       ...         ...            ...          ...
# 9393   18988            Low      0.02      276.20          24.49         3396
# 9394   19370           High      0.00      140.98          53.48         3396
# 9408   22194           High      0.00      160.98          35.02         3398
# 9420   18329           High      0.08      212.60          52.20         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
#
# ...

# %%
#7.display records where product category is furniture
data.loc[data["Product Category"]=="Furniture"]
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 7      20228  Not Specified      0.02      500.98          26.00            5
# 14     20876         Medium      0.08      140.98          36.09            8
# 15     20877         Medium      0.10      286.85          61.76            9
# 17     21776       Critical      0.06        9.48           7.29           11
# 19     24844         Medium      0.09       78.69          19.99           14
# ...      ...            ...       ...         ...            ...          ...
# 9408   22194           High      0.00      160.98          35.02         3398
# 9413   24911         Medium      0.10        9.38           4.93         3400
# 9420   18329           High      0.08      212.60          52.20         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
#
# ...

# %%
# values_count()
#1.count the number of orders in each region.
data["Region"].value_counts().sort_values()
# Out:
# Region
# South      1954
# West       2284
# East       2289
# Central    2899
# Name: count, dtype: int64

# %%
#2.count the number of customers in each Customer Segment.
data["Customer Segment"].value_counts()
# Out:
# Customer Segment
# Corporate         3375
# Home Office       2316
# Consumer          1894
# Small Business    1841
# Name: count, dtype: int64

# %%
#3.count the number of products in each Product Category.
data["Product Category"].value_counts()
# Out:
# Product Category
# Office Supplies    5181
# Technology         2312
# Furniture          1933
# Name: count, dtype: int64

# %%
#4.count the number of orders by Ship Mode.
data["Ship Mode"].value_counts()
# Out:
# Ship Mode
# Regular Air       7036
# Delivery Truck    1283
# Express Air       1107
# Name: count, dtype: int64

# %%
#5.count the number of products in each Product Sub-Category.
data["Product Sub-Category"].value_counts()
# Out:
# Product Sub-Category
# Paper                             1379
# Binders and Binder Accessories    1028
# Telephones and Communication       992
# Office Furnishings                 883
# Computer Peripherals               846
# Pens & Art Supplies                721
# Storage & Organization             610
# Appliances                         492
# Chairs & Chairmats                 440
# Tables                             404
# Office Machines                    376
# Labels                             329
# Envelopes                          272
# Bookcases                          206
# Rubber Bands                       195
# Scissors, Rulers and Trimmers      155
# Copiers and Fax                     98
# Name: count, dtype: int64

# %%
#6.count the number of orders in each Order Priority.
data["Order Priority"].value_counts()
# Out:
# Order Priority
# High             1970
# Low              1926
# Not Specified    1881
# Medium           1844
# Critical         1804
# Critical            1
# Name: count, dtype: int64

# %%
#7.count the number of records for each State or Province.
data["State or Province"].value_counts()
# Out:
# State or Province
# California              1021
# Texas                    646
# Illinois                 584
# New York                 574
# Florida                  522
# Ohio                     396
# Washington               327
# Michigan                 327
# Pennsylvania             271
# North Carolina           251
# Indiana                  241
# Minnesota                239
# Massachusetts            222
# Georgia                  214
# Virginia                 198
# Maryland                 178
# Colorado                 177
# New Jersey               177
# Wisconsin                169
# Oregon                   168
# Tennessee                166
# Missouri                 161
# Iowa                     156
# Utah                     146
# Arizona                  134
# Kansas                   133
# Maine                    128
# Alabama                  125
# Arkansas                 123
# Idaho                    114
# South Carolina           105
# ...

# %%
# sort_values()
#1.sort the dataset by Sales in ascending order.
data["Sales"].sort_values()
# Out:
# 4369         1.32
# 932          1.62
# 2770         1.65
# 7511         2.24
# 62           2.25
#           ...
# 1418     43046.20
# 4642     45737.33
# 7040     48418.58
# 7013     50332.66
# 8461    100119.16
# Name: Sales, Length: 9426, dtype: float64

# %%
#2.Sort the dataset by Sales in discending order.
data["Sales"].sort_values(ascending=False)
# Out:
# 8461    100119.16
# 7013     50332.66
# 7040     48418.58
# 4642     45737.33
# 1418     43046.20
#           ...
# 1066         2.25
# 7511         2.24
# 2770         1.65
# 932          1.62
# 4369         1.32
# Name: Sales, Length: 9426, dtype: float64

# %%
#3.sort the dataset by Porfit from highest to lowest.
data["Profit"].sort_values(ascending=False)
# Out:
# 9132    16332.414000
# 4189    12504.904500
# 9404    11429.477400
# 4642     9228.225600
# 859      9195.975000
#             ...
# 5402   -13562.637408
# 4844   -13706.464000
# 7800   -14140.701600
# 4338   -14369.123580
# 4659   -16476.838000
# Name: Profit, Length: 9426, dtype: float64

# %%
#4.sort the dataset by Customer Name alphabetically.
data["Customer Name"].sort_values()
# Out:
# 8946    Aaron Davies Bruce
# 8945    Aaron Davies Bruce
# 8943    Aaron Davies Bruce
# 8944    Aaron Davies Bruce
# 4323             Aaron Day
#                ...
# 3419        Zachary Potter
# 3418        Zachary Potter
# 3420        Zachary Potter
# 1316            Zachary Wu
# 2073            Zachary Yu
# Name: Customer Name, Length: 9426, dtype: object

# %%
#5.sort the dataset by Region and then Sales.
data["Region"].sort_values()
# Out:
# 0       Central
# 4406    Central
# 4407    Central
# 4408    Central
# 4409    Central
#          ...
# 4630       West
# 4629       West
# 4628       West
# 7523       West
# 9425       West
# Name: Region, Length: 9426, dtype: object

# %%
data["Sales"].sort_values()
# Out:
# 4369         1.32
# 932          1.62
# 2770         1.65
# 7511         2.24
# 62           2.25
#           ...
# 1418     43046.20
# 4642     45737.33
# 7040     48418.58
# 7013     50332.66
# 8461    100119.16
# Name: Sales, Length: 9426, dtype: float64

# %%
#6.sort the dataset by Discount in descending order.
data["Discount"].sort_values(ascending=False)
# Out:
# 8649    0.25
# 8661    0.21
# 5991    0.17
# 6000    0.16
# 5990    0.11
#         ...
# 3749    0.00
# 1109    0.00
# 7329    0.00
# 7334    0.00
# 2582    0.00
# Name: Discount, Length: 9426, dtype: float64

# %%
#7.sort the dataset by Order Date from oldest to newest.
data["Order Date"].sort_values
# Out:
# <bound method Series.sort_values of 0      2012-05-28
# 1      2010-07-07
# 2      2011-07-27
# 3      2011-07-27
# 4      2011-07-27
#           ...
# 9421   2013-05-14
# 9422   2013-05-14
# 9423   2013-09-12
# 9424   2010-02-08
# 9425   2013-09-12
# Name: Order Date, Length: 9426, dtype: datetime64[ns]>

# %%
# AND(&)
#1.Display records where Sales>500 and Profit>100.
import pandas as pd
data=pd.read_excel("Pandas(5).xlsx")
    
data[(data['Sales']>500)&(data['Profit']>100)]
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 4      23088  Not Specified      0.00      205.99           2.50            3
# 5      23597         Medium      0.09       55.48          14.30            3
# 6      25549            Low      0.08      120.97          26.30            3
# 7      20228  Not Specified      0.02      500.98          26.00            5
# 9      24782           High      0.01       90.24           0.99            6
# ...      ...            ...       ...         ...            ...          ...
# 9408   22194           High      0.00      160.98          35.02         3398
# 9410   26073       Critical      0.05       59.78          10.29         3399
# 9417   23413       Critical      0.07      115.79           1.99         3400
# 9419   24912         Medium      0.05       35.99           1.25         3400
# 9424   25914           High      0.10      105.98          13.99         3403
#
# ...

# %%
#2.Dispaly customers from the West region and Furniture category.
data[(data["Region"]=="West") & (data["Product Category"]=="Furniture")]
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 7      20228  Not Specified      0.02      500.98          26.00            5
# 35     23890           High      0.05       26.48           6.93           18
# 39     20578            Low      0.02      110.98          30.00           18
# 57     19249           High      0.05       14.34           5.00           23
# 60     18478            Low      0.10      146.05          80.20           23
# ...      ...            ...       ...         ...            ...          ...
# 9254   25880         Medium      0.08       29.18           8.55         3352
# 9259   22914  Not Specified      0.01       18.65           3.77         3354
# 9270   18629         Medium      0.03      160.98          30.00         3356
# 9386   18429           High      0.03      160.98          30.00         3393
# 9424   25914           High      0.10      105.98          13.99         3403
#
# ...

# %%
#3.display records where Discount>0.05 and Shipping Cost>20.
data[(data["Discount"]>0.05) & (data["Shipping Cost"])]
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 5      23597         Medium      0.09       55.48          14.30            3
# 6      25549            Low      0.08      120.97          26.30            3
# 8      19483            Low      0.08        6.48           6.81            5
# 10     24563       Critical      0.07        6.48           6.60            6
# 12     24565       Critical      0.10       85.99           0.99            6
# ...      ...            ...       ...         ...            ...          ...
# 9420   18329           High      0.08      212.60          52.20         3402
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
# ...

# %%
#4.display orders where Quantity ordered new>10 and Profit>50.
data[(data["Quantity ordered new"]>10) & (data["Profit"]>50)]
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 5      23597         Medium      0.09       55.48          14.30            3
# 6      25549            Low      0.08      120.97          26.30            3
# 7      20228  Not Specified      0.02      500.98          26.00            5
# 9      24782           High      0.01       90.24           0.99            6
# 11     24564       Critical      0.01        4.84           0.71            6
# ...      ...            ...       ...         ...            ...          ...
# 9410   26073       Critical      0.05       59.78          10.29         3399
# 9411   26074       Critical      0.05        4.13           0.50         3399
# 9419   24912         Medium      0.05       35.99           1.25         3400
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
# ...

# %%
#5.display products where Product Category=Office Supplies and Sales>1000.
data[(data["Product Category"]=="Office Supplies")&(data["Sales"]>1000)]
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 5      23597         Medium      0.09       55.48          14.30            3
# 9      24782           High      0.01       90.24           0.99            6
# 51      3763       Critical      0.08       42.98           4.62           21
# 53      7082  Not Specified      0.06       64.65          35.00           21
# 58     19250           High      0.00       30.98           8.74           23
# ...      ...            ...       ...         ...            ...          ...
# 9377   23192       Critical      0.04      167.27          35.00         3386
# 9400   20624            Low      0.00     1270.99          19.99         3397
# 9404   22193           High      0.05      387.99          19.99         3397
# 9406   22599       Critical      0.01      177.98           0.99         3398
# 9410   26073       Critical      0.05       59.78          10.29         3399
#
# ...

# %%
#6.display records where Region=Central and Profit<0.
data[(data["Region"]=="Central")&(data["Profit"]>0)]
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 19     24844         Medium      0.09       78.69          19.99           14
# 102    20936         Medium      0.10        7.08           2.35           39
# 111    23651         Medium      0.10       39.48           3.99           45
# 116    19337         Medium      0.07        4.13           0.50           48
# ...      ...            ...       ...         ...            ...          ...
# 9407   23074            Low      0.01      155.99           8.99         3398
# 9408   22194           High      0.00      160.98          35.02         3398
# 9410   26073       Critical      0.05       59.78          10.29         3399
# 9411   26074       Critical      0.05        4.13           0.50         3399
# 9412   26075       Critical      0.01       30.98          17.08         3399
#
# ...

# %%
#7.display orders where Ship Mode=Regular Air and Sales>200.
data[(data["Ship Mode"]=="Regular Air")&(data["Sales"]>200)]
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 9      24782           High      0.01       90.24           0.99            6
# 12     24565       Critical      0.10       85.99           0.99            6
# 13     21866           High      0.05       12.28           4.86            7
# 16     22241       Critical      0.06       15.57           1.39           10
# 17     21776       Critical      0.06        9.48           7.29           11
# ...      ...            ...       ...         ...            ...          ...
# 9410   26073       Critical      0.05       59.78          10.29         3399
# 9412   26075       Critical      0.01       30.98          17.08         3399
# 9417   23413       Critical      0.07      115.79           1.99         3400
# 9419   24912         Medium      0.05       35.99           1.25         3400
# 9421   20275       Critical      0.06       35.89          14.72         3402
#
# ...

# %%
# OR(|)
#1.display records where Region=East or Region=West.
data[(data["Region"]=="East")|(data["Region"]=="West")]
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# 5      23597         Medium      0.09       55.48          14.30            3
# ...      ...            ...       ...         ...            ...          ...
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
# ...

# %%
#2.dispaly products where Product Category=Furniture or Technology.
data[(data["Product Category"]=="Furniture")|(data["Product Category"]=="Technology")]
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 4      23088  Not Specified      0.00      205.99           2.50            3
# 6      25549            Low      0.08      120.97          26.30            3
# 7      20228  Not Specified      0.02      500.98          26.00            5
# 12     24565       Critical      0.10       85.99           0.99            6
# 14     20876         Medium      0.08      140.98          36.09            8
# ...      ...            ...       ...         ...            ...          ...
# 9417   23413       Critical      0.07      115.79           1.99         3400
# 9419   24912         Medium      0.05       35.99           1.25         3400
# 9420   18329           High      0.08      212.60          52.20         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
#
# ...

# %%
#3.Display records where Sales>1000 or Profit>500.
data[(data["Sales"]>1000)|(data["Profit"]>500)]
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 4      23088  Not Specified      0.00      205.99           2.50            3
# 5      23597         Medium      0.09       55.48          14.30            3
# 6      25549            Low      0.08      120.97          26.30            3
# 7      20228  Not Specified      0.02      500.98          26.00            5
# 9      24782           High      0.01       90.24           0.99            6
# ...      ...            ...       ...         ...            ...          ...
# 9408   22194           High      0.00      160.98          35.02         3398
# 9410   26073       Critical      0.05       59.78          10.29         3399
# 9417   23413       Critical      0.07      115.79           1.99         3400
# 9420   18329           High      0.08      212.60          52.20         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
#
# ...

# %%
#4.display orders where discount>0.10 or Shipping Cost>30.
data[(data["Discount"]>0.10)|(data["Shipping Cost"]>30)]
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 14     20876         Medium      0.08      140.98          36.09            8
# 15     20877         Medium      0.10      286.85          61.76            9
# 42     25082  Not Specified      0.06       64.65          35.00           20
# 53      7082  Not Specified      0.06       64.65          35.00           21
# 60     18478            Low      0.10      146.05          80.20           23
# ...      ...            ...       ...         ...            ...          ...
# 9378   19464  Not Specified      0.03       95.99          35.00         3388
# 9394   19370           High      0.00      140.98          53.48         3396
# 9408   22194           High      0.00      160.98          35.02         3398
# 9420   18329           High      0.08      212.60          52.20         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
#
# ...

# %%
#5.display customers from California or Texas.
data[(data["State or Province"]=="California")|(data["State or Province"]=="Texas")]
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 7      20228  Not Specified      0.02      500.98          26.00            5
# 8      19483            Low      0.08        6.48           6.81            5
# 9      24782           High      0.01       90.24           0.99            6
# 10     24563       Critical      0.07        6.48           6.60            6
# 11     24564       Critical      0.01        4.84           0.71            6
# ...      ...            ...       ...         ...            ...          ...
# 9267   24781       Critical      0.03        7.64           1.39         3355
# 9268   22916  Not Specified      0.01       46.89           5.10         3355
# 9378   19464  Not Specified      0.03       95.99          35.00         3388
# 9379   19774            Low      0.00        3.28           0.98         3388
# 9380   22719           High      0.04        5.40           7.78         3388
#
# ...

# %%
#6.dispaly orders where ship Mode=Express Air or Dilivery Truck.
data[(data["Ship Mode"]=="Express Air")|(data["Ship Mode"]=="Delivery Truck")]
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# 5      23597         Medium      0.09       55.48          14.30            3
# 6      25549            Low      0.08      120.97          26.30            3
# ...      ...            ...       ...         ...            ...          ...
# 9413   24911         Medium      0.10        9.38           4.93         3400
# 9420   18329           High      0.08      212.60          52.20         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
# ...

# %%
#7. display records where Profit<0 or Sales>2000.
data[(data["Profit"]<0)|(data["Sales"]>2000)]
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 5      23597         Medium      0.09       55.48          14.30            3
# 7      20228  Not Specified      0.02      500.98          26.00            5
# 8      19483            Low      0.08        6.48           6.81            5
# ...      ...            ...       ...         ...            ...          ...
# 9415   26043  Not Specified      0.06       30.98           6.50         3400
# 9418   23414       Critical      0.02       37.44           4.27         3400
# 9420   18329           High      0.08      212.60          52.20         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
#
# ...

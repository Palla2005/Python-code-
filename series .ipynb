# %%
import pandas as pd
import numpy as np
s1=pd.Series({"Name":"Pallavi","Sur_name":"Lone","Country":"India"},name="The Opener")
print(s1)
# Out:
# Name        Pallavi
# Sur_name       Lone
# Country       India
# Name: The Opener, dtype: object

# %%
import pandas as pd
import numpy as np
s1=pd.Series({"Name":"Rohit","Sur_name":"Sharma","Country":"India","TPL_Team":"Mumbai Indian"},name="The Opener")
print(s1)
# Out:
# Name                Rohit
# Sur_name           Sharma
# Country             India
# TPL_Team    Mumbai Indian
# Name: The Opener, dtype: object

# %%
import pandas as pd
import numpy as np
s1=pd.Series({"Name":"Rohit","Sur_name":"Sharma","Country":"India","TPL_Team":"Mumbai Indian"},name="The Opener")
s1["Sur_name"]
# Out:
# 'Sharma'

# %%
#particular indexing
s2=pd.Series(np.random.choice(np.arange(10,250),size=10),index=range(1,11))
print(s2)
# Out:
# 1      73
# 2     123
# 3      52
# 4     238
# 5     190
# 6      88
# 7     193
# 8     173
# 9     126
# 10    175
# dtype: int64

# %%
s2=pd.Series(np.random.choice(np.arange(10,250),size=10),index=range(1,11))
s2.is_unique
print(s2)
# Out:
# 1     197
# 2      43
# 3     242
# 4     115
# 5     181
# 6      92
# 7     234
# 8     120
# 9     106
# 10     34
# dtype: int64

# %%
import pandas as pd
import numpy as np
s1=pd.Series({"Name":"Rohit","Sur_name":"Sharma","Country":"India"},name="The Opener")
s1
# Out:
# Name         Rohit
# Sur_name    Sharma
# Country      India
# Name: The Opener, dtype: object

# %%
s1["Name":"Country"]
# Out:
# Name         Rohit
# Sur_name    Sharma
# Country      India
# Name: The Opener, dtype: object

# %%
s2[6]
# Out:
# np.int64(92)

# %%
s2[6:11]
# Out:
# 7     234
# 8     120
# 9     106
# 10     34
# dtype: int64

# %%
s2[6:11:2]
# Out:
# 7    234
# 9    106
# dtype: int64

# %%
s1
# Out:
# Name         Rohit
# Sur_name    Sharma
# Country      India
# Name: The Opener, dtype: object

# %%
s1["Sur_name":"TPL_Team"]
# Out:
# Sur_name           Sharma
# Country             India
# TPL_Team    Mumbai Indian
# Name: The Opener, dtype: object

# %%
s1
# Out:
# Name                Rohit
# Sur_name           Sharma
# Country             India
# TPL_Team    Mumbai Indian
# Name: The Opener, dtype: object

# %%
s2[1]
# Out:
# np.int64(197)

# %%
s2[-1]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\range.py:413, in RangeIndex.get_loc(self, key)
#     412 try:
# --> 413     return self._range.index(new_key)
#     414 except ValueError as err:
#
# ValueError: -1 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 s2[-1]
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\series.py:1133, in Series.__getitem__(self, key)
#    1130     return self._values[key]
#    1132 elif key_is_scalar:
# -> 1133     return self._get_value(key)
#    1135 # Convert generator to list before going through hashable part
#    1136 # (We will iterate through the generator there to check for slices)
# ...

# %%
s2[3:7]
# Out:
# 4    115
# 5    181
# 6     92
# 7    234
# dtype: int64

# %%
# fancy indexing-2D index
s2=pd.Series(np.random.choice(np.arange(10,250),size=10),index=range(1,11))
s2[[2,6,8]]
# Out:
# 2    153
# 6    148
# 8     70
# dtype: int64

# %%
`#Mathematical functions

# %%
s2.mean()
# Out:
# np.float64(136.4)

# %%
s2.min()
# Out:
# 27

# %%
s2.max()
# Out:
# 235

# %%
s1
# Out:
# Name                Rohit
# Sur_name           Sharma
# Country             India
# TPL_Team    Mumbai Indian
# Name: The Opener, dtype: object

# %%
# doller to rupees
doller=float(input("Enter a doller"))
rupees=doller*85.5
print("Ruppes:",rupees)
# Out:
# Enter a doller 10
# Ruppes: 855.0

# %%
# kilomerer to meter
km=float(input("Enter to kilometer"))
meter=km*100
print("Meter:",meter)
# Out:
# Enter to kilometer 20
# Meter: 2000.0

# %%
# price of kg 7 apples
price_per_kg=120
price=price_per_kg*7
print("price of 7 kg apples=",price)
# Out:
# price of 7 kg apples= 840

# %%
#salary with 10% increment
salary=float(input("Enter salary:"))
new_salary=salary+(salary*10/100)
print("New Salary=",new_salary)
# Out:
# Enter salary: 50000
# New Salary= 55000.0

# %%
# calories burned in 4000 steps
steps=4000
km=steps/1300
calories=km*12
print("Calories Burned=",calories)
# Out:
# Calories Burned= 36.92307692307693

# %%
# sun,difference,product,quotient
a=float(input("Entere first number:"))
b=float(input("Entere second number:"))
print("Sum=", a+b)
print("Difference=",a-b)
print("Product=",a*b)
print("Quotient=",a/b)
# Out:
# Entere first number: 10
# Entere second number: 2
# Sum= 12.0
# Difference= 8.0
# Product= 20.0
# Quotient= 5.0

# %%
# name and age introduction
name=input("Enter name:")
age=int(input("Enter age:"))
print("My name is",name, "and I am",age,"year old.")
# Out:
# Enter name: pallvi
# Enter age: 19
# My name is pallvi and I am 19 year old.

# %%
# float to integer
num=float(input("Enter a float value:"))
integer_value=int(num)
print("Float value=",num)
print("Integer value=",integer_value)
# Out:
# Enter a float value: 12.45
# Float value= 12.45
# Integer value= 12

# %%
# swap two variable
a=int(input("Enter first number:"))
b=int(input("Enter second number:"))
print("Before Swapping:",a,b)
a,b=b,a
print("After Swapping:",a,b)
# Out:
# Enter first number: 10
# Enter second number: 30
# Before Swapping: 10 30
# After Swapping: 30 10

# %%
# Average 3 numbers
a=int(input("Enter first numebr"))
b=int(input("Enter second numebr"))
c=int(input("Enter third numebr"))
avg=(a+b+c)/6
print("Average:",avg)
# Out:
# Enter first numebr 24
# Enter second numebr 32
# Enter third numebr 12
# Average: 11.333333333333334

# %%
# area of rectangle
length=int(input("Enter length:"))
breath=int(input("Enter breath:"))
area=length*breath
print("Area:",area)
# Out:
# Enter length: 20
# Enter breath: 5
# Area: 100

# %%
#count words in a sentence
sentence=input("Enter a sentence:")
words=sentence.split()
print("Number of word=",len(words))
# Out:
# Enter a sentence: I love python programming
# Number of word= 4

# %%
# check if two inputs are equal
a=int(input("Enter first value:",))
b=int(input("Enter second value:",))
print("Equal=",a==b)
# Out:
# Enter first value: 10
# Enter second value: 10
# Equal= True

# %%
#arithematic operators
a=int(input("Enter first number:"))
b=int(input("Enter second number:"))
print("Addition=",a+b)
print("Subsraction=",a-b)
print("Multiplication=",a*b)
print("Division=",a/b)
print("Module=",a%b)
print("Floor division=",a//b)
print("Exponent=",a**b)
# Out:
# Enter first number: 10
# Enter second number: 20
# Addition= 30
# Subsraction= -10
# Multiplication= 200
# Division= 0.5
# Module= 10
# Floor division= 0
# Exponent= 100000000000000000000

# %%
# square and cube of a number
num=int(input("Enter a number:"))
print("Square=",num**2)
print("Cube=",num**3)
# Out:
# Enter a number: 5
# Square= 25
# Cube= 125

# %%
 Day3-Type casting, Data types,user interaction

# %%
# cancatenate two strings
str1=input("Enter first string:")
str2=input("Enter second string:")
result=str1+" "+str2
print("Result=",result)
# Out:
# Enter first string: Hello
# Enter second string: world
# Result= Hello world

# %%
# convert string number to integer and add
num1=input("Enter first number:")
num2=input("Enter second number:")
sum=int(num1)+int(num2)
print("Sum=",sum)
# Out:
# Enter first number: 10
# Enter second number: 20
# Sum= 30

# %%
# type before and after casting
num="25"
print("Before:",type(num))
num=int(num)
print("After:",type(num))
# Out:
# Before: <class 'str'>
# After: <class 'int'>

# %%
#list of 5 student names
students=["Pallavi","Isha","Tanjil","Aditi","Pranali",]
print("2nd Name=",students[1])
print("4th Name=",students[3])
# Out:
# 2nd Name= Isha
# 4th Name= Aditi

# %%
#Tuple of subjects
subjects=("python","c++", "java")
for sub in subjects:
    print(sub)
# Out:
# python
# c++
# java

# %%
# dictionary student:marks
marks={"Pallavi":84,"Riya":75,"Isha":90}
for key, value in marks. items():
      print(key, ":",value)
# Out:
# Pallavi : 84
# Riya : 75
# Isha : 90

# %%
# store input in set
a=input("Enter first value:")
b=input("Enter second value:")
c=input("Enter third value:")
s={a,b,c}
print("Set=",s)
# Out:
# Enter first value: 10
# Enter second value: 20
# Enter third value: 30
# Set= {'30', '20', '10'}

# %%
# integer to float and float to integer
num=10
f=float(num)
x=15.8
i=int(x)
print("Float=",f)
print("Integer=",i)
# Out:
# Float= 10.0
# Integer= 15

# %%
# float to string
num=45.75
result=str(num)
print(result)
print(type(result))
# Out:
# 45.75
# <class 'str'>

# %%
# booleand to interger
value=True
num=int(value)
print("Integer=",num)
# Out:
# Integer= 1

# %%
# Display types of variables
a=10
b="python"
c=10.5
print(type(a))
print(type(b))
print(type(c))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>

# %%
# favorite quote in uppercase
quote=input("Enter your favorite quote:")
print(quote.upper())
# Out:
# Enter your favorite quote: never given up NEVER GIVE UP
# NEVER GIVEN UP NEVER GIVE UP

# %%
#nultiply two numbers and check>100
a=int(input("Enter first number:"))
b=int(input("Enter second number:"))
result=a*b
print("Multiplicaion=",result)
print(result>100)
# Out:
# Enter first number: 15
# Enter second number: 10
# Multiplicaion= 150
# True

# %%
# implicit type conversion
a=10
b=5.5
result=a+b
print(result)
print(type(result))
# Out:
# 15.5
# <class 'float'>

# %%
# ASCII value of a character
ch=input("Enter a character:")
print("ASCII value=",ord(ch))
# Out:
# Enter a character: A
# ASCII value= 65

# %%
Day 2-Conditionals and Logical operations

# %%
# check whether a number is divisible by 5
num=int(input("Enter a number:"))
if num%5==0:
   print("Divisible by 5")
else:
   print("Not divisible by 5")
# Out:
# Enter a number: 20
# Divisible by 5

# %%
# check voting eligibility(18+)
age=int(input("Enter age:"))
if age>=18:
    print("Eligible for voting")
else:
    print("Not eligible for voting")
# Out:
# Enter age: 20
# Eligible for voting

# %%
# positive, Negative, or zero
num=int(input("Enter a number:"))
if num>0:
    print("Positive")
elif num<0:
    print("Negative")
else:
    print("Zero")
# Out:
# Enter a number: -5
# Negative

# %%
# profit or loss
cp=float(input("Enter cost price:"))
sp=float(input("Enter selling price:"))
if sp>cp:
    print("Profit=",sp-cp)
elif cp>sp:
    print("Loss=",cp-sp)
else:
    print("No profit No Loss")
# Out:
# Enter cost price: 100
# Enter selling price: 150
# Profit= 50.0

# %%
# Attendance check
total=int(input("Enter total classes:"))
attended=int(input("Enter attended classes:"))
attendance=(attended/total)*100
if attendance>=75:
    print("Allowed in exam")
else:
    print("Not allowed in exam")
# Out:
# Enter total classes: 100
# Enter attended classes: 80
# Allowed in exam

# %%
# electricity bill
units=int(input("Enter units:"))
if units<=100:
    bill=0
elif units<=200:
    bill=(units-100)*5
else:
    bill=(100*5)+(units-200)*10
    print("Bill=",bill)
# Out:
# Enter units: 250
# Bill= 1000

# %%
# Bike road tax
price=float(input("Enter bike cost price:"))
if price>100000:
    tax=price*0.15
elif price>50000:
    tax=price*0.10
else:
    tax=price*0.05
print("Road Tax=",tax)
# Out:
# Enter bike cost price: 80000
# Road Tax= 8000.0

# %%
# weekday name
day=int(input("Enter number(1-7):"))
if day==1:
    print("Sunday")
elif day==2:
    print("Monday")
elif day==3:
    print("Tuesday")
elif day==4:
    print("Wednesday")
elif day==5:
    print("Thursday")
elif day==6:
    print("Friday")
elif day==7:
    print("Saturday")
else:
    print("Invalid input")
# Out:
# Enter number(1-7): 2
# Monday

# %%
# Even or odd
num=int(input("Enter a number:"))
if num %2==0:
    print("Even")
else:
    print("odd")
# Out:
# Enter a number: 8
# Even

# %%
# largest of three numbers
a=int(input("Enter first number:"))
b=int(input("Enter second number:"))
c=int(input("Enter third number:"))
if a>=b and a>=c:
    print("Largest=",a)
elif b>=a and b>=c:
    print("Largest=",b)
else:
    print("Largest=",c)
# Out:
# Enter first number: 10
# Enter second number: 25
# Enter third number: 15
# Largest= 25

# %%
# leap year
year=int(input("Enter year:"))
if year%4==0:
    print("Leap Year")
else:
    print("Not a Leap Year")
# Out:
# Enter year: 2024
# Leap Year

# %%
# grade calculation
marks=int(input("Enter marks:"))
if marks>=90:
    print("Grade A")
elif marks>=75:
    print("Grade B")
elif marks>=50:
    print("Grade C")
else:
    print("Fail")
# Out:
# Enter marks: 85
# Grade B

# %%
# vowel or consonant
ch=input("Enter a character:")
if ch in "aeiouAEIOU":
    print("Vowel")
else:
    print("Consonant")
# Out:
# Enter a character: a
# Vowel

# %%
# Number between 10 and 100
num=int(input("Enter a number:"))
if num>=10 and num<=100:
    print("Number lies between 10 and 100")
else:
    print("Number does not lie between 10 and 100")
# Out:
# Enter a number: 50
# Number lies between 10 and 100

# %%
# Divisible by Both 3 and 7
num=int(input("Enter a number:"))
if num%3==0 and num%7==0:
   print("Divisible by both 3 and 7")
else:
   print("Not divisible by both 3 and 7")
# Out:
# Enter a number: 21
# Divisible by both 3 and 7

# %%
section-D

# %%
# take a string input and print each character
s=input("Enter a string:")
for ch in s:
    print(ch)
# Out:
# Enter a string: Hello
# H
# e
# l
# l
# o

# %%
# count total number of characters in a string
s=input("Enter a string:")
print("Total characters=",len(s))
# Out:
# Enter a string: Hello
# Total characters= 5

# %%
# count number of vowels in a string
s=input("Enter a string:")
count=0
for ch in s:
    if ch in "aeiouAEIOU":
        count+=1
print("Vowels=",count)
# Out:
# Enter a string: Education
# Vowels= 5

# %%
# reverse a string using slicing
s=input("Enter a string:")
print("Reverse=",s[::-1])
# Out:
# Enter a string: Python
# Reverse= nohtyP

# %%
# check whether a string is palindrome or not
s=input("Enter a string:")
if s==s[::-1]:
    print("Palindrome")
else:
    print("Not Palindrome")
# Out:
# Enter a string: madam
# Palindrome

# %%
# canncatenate two strings entered by user
s1=input("Enter first string:")
s2=input("Enter second string:")
print("Result=", s1+s2)
# Out:
# Enter first string: Good
# Enter second string: Morning
# Result= GoodMorning

# %%
# print characters at evern index positions
s=input("Entere a string:")
for i in range(0,len(s),2):
    print(s[i])
# Out:
# Entere a string: python
# p
# t
# o

# %%
# find length of string without using len()
s=input("Enter a string:")
count=0
for ch in s:
    count+=1
print("Length=",count)
# Out:
# Enter a string: Python
# Length= 6

# %%
section E

# %%
# count number of words in a sentence
s=input("Enter a sentence:")
count=1
for ch in s:
    if ch ==" ":
        count+=1
print("Words=",count)
# Out:
# Enter a sentence: I Love Python
# Words= 3

# %%
# count alphabets, digits and special characters
s=input("Enter a string:")
alpha=digit=special=0
for ch in s:
    if ch.isalpha():
        alpha+=1
    elif ch.isdigit():
        digit+=1
    else:
        special+=1
print("Alphabets=",alpha)
print("Digits=",digit)
print("Special Character=",special)
# Out:
# Enter a string: abc123@
# Alphabets= 3
# Digits= 3
# Special Character= 1

# %%
# Remove all spaces form a string
s=input("Enter a string:")
result=""
for ch in s:
    if ch !=" ":
        result+=ch
print(result)
# Out:
# Enter a string: I Love Python
# ILovePython

# %%
# # replace all vowels with '*'
s=input("Enter a string:")
result=""
for ch in s:
    if ch in "aeiouAEIOU":
        result+= "*"
    else:
        result+=ch
print(result)
# Out:
# Enter a string: Education
# *d*c*t**n

# %%
# ectract digits from a string and find their sum
s=input("Enter a string:")
sum=0
for ch in s:
    if ch.isdigit():
        sum+=int(ch)
print("Sum=",sum)
# Out:
# Enter a string: abc123
# Sum= 6

# %%
# convert entire string to uppercase without using upper()
s=input("Enter a string:")
result=""
for ch in s:
    if 'a'<=ch <='z':
        result+=chr(ord(ch)-32)
    else:
        result+=ch
print(result)
# Out:
# Enter a string: hello
# HELLO

# %%
# replace spaces with'_'
s=input("Entere a string:")
resul=""
for ch in s:
    if ch==" ":
        result+="_"
    else:
        result+=ch
print(result)
# Out:
# Entere a string: I Love Python
# HELLOI_Love_Python

# %%
# count occurrence of a character (using loop)
s=input("Enter a string:")
c=input("jEnter a characer:")
count=0
for ch in s:
    if ch==c:
         count+=1
print("Occurrence=",count)
# Out:
# Enter a string: banana
# jEnter a characer: a
# Occurrence= 3

# %%
# print string in reverse without slicing
s=input("Enter a string:")
i=len(s)-1
while i>=0:
    print(s[i],end="")
    i-=1
# Out:
# Enter a string: Python
# nohtyP

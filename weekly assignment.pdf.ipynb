# %%
# replace all odd numbers with their squares
st1=[1,2,3,4,5]
for i in range(len(st1)):
    if st1[i]%2!=0:
       st1[i]=st1[i]**2
print(st1)
# Out:
# [1, 2, 9, 4, 25]

# %%
# Remove all elements greate than 50
st1=[10,20,30,40,50]
result=[]
for x in st1:
    if x<=50:
       result.append(x)
print(result)
# Out:
# [10, 20, 30, 40, 50]

# %%
# merge two lists and remove dduplicates
a=[1,2,3]
b=[3,4,5]
result=[]
for x in a+b:
    if x not in result:
        result.append(x)
print(result)
# Out:
# [1, 2, 3, 4, 5]

# %%
# reverse a list without reverse() ore slicing
st1=[1,2,3,4,5]
rev=[]
for i in range(len(st1)-1,-1,-1):
    rev.append(st1[i])
print(rev)
# Out:
# [5, 4, 3, 2, 1]

# %%
# Rotate a list to the right by 2 positions
st1=[1,2,3,4,5]
rotated=[st1[-2], st1[-1]]+st1[:-2]
print(rotated)
# Out:
# [4, 5, 1, 2, 3]

# %%
# check if two lists are wqual
a=[1,2,3]
b=[1,2,3]
print(a==b)
# Out:
# True

# %%
# sum of elements at even indexes
st1=[10,20,30,40,50]
s=0
for i in range(0, len(st1),2):
    s+=st1[i]
print(s)
# Out:
# 90

# %%
# words longer than 5 letters
sentence="Python programming language is powerful"
words=sentence.split()
result=[w for w in words if len(w)>5]
print(result)
# Out:
# ['Python', 'programming', 'language', 'powerful']

# %%
# nested list(2D) and access rows/columns
mat=[[1,2,3,],[4,5,6],[7,8,9]]
print(mat[1])
print(mat[0][2])
# Out:
# [4, 5, 6]
# 3

# %%
# count even and odd numbers
st1=[1,2,3,4,5,6]
even=odd=0
for x in st1:
    if x%2==0:
        even+=1
    else:
        odd+=1
print("Even=",even)
print("Odd=",odd)
# Out:
# Even= 3
# Odd= 3

# %%
# find minumum and maximum without built-in functions
st1=[10,5,20,3,15]
small=large=st1[0]
for x in st1:
    if x<small:
       small=x
    if x>large:
        large=x
print("Min=",small)
print("Max=",large)
# Out:
# Min= 3
# Max= 20

# %%
# remove duplicates without set()
st1=[1,2,2,3,4,4,5]
result=[]
for x in st1:
    if x not in result:
        result.append(x)
print(result)
# Out:
# [1, 2, 3, 4, 5]

# %%
# flatten a nestedd list
st1=[[1,2,],[3,4],[5,6,]]
flat=[]
for sub in st1:
    for item in sub:
        flat.append(item)
print(flat)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
# find common elements between two lists
a=[1,2,3,4]
b=[3,4,5,6]
common=[]
for x in a:
    if x in b:
        common.append(x)
print(common)
# Out:
# [3, 4]

# %%
# find the second largest number without sort()
st1=[10,20,30,40,50]
largest=second=-1
for n in st1:
    if n>largest:
       second=largest
       largest=n
    elif n> second and n!=largest:
       secon=n
print(second)
# Out:
# 40

# %%
 section D

# %%
# count frequency of each world
s="apple banana apple mange banana"
words=s.split()
for w in set(words):
    print(w,":", words.count(w))
# Out:
# mange : 1
# apple : 2
# banana : 2

# %%
# extract digits and sum them
s="a1b2c3d4"
total=0
for ch in s:
    if ch.isdigit():
        total+=int(ch)
print("Sum=",total)
# Out:
# Sum= 10

# %%
# find the longest word
s="Python is a powerful programming language"
words=s.split()
longest=max(words,key=len)
print(longest)
# Out:
# programming

# %%
# check if two strings are anagrams
s1="listen"
s2="silent"
if sorted(s1)==sorted(s2):
    print("Anagram")
else:
    print("Not Anagram")
# Out:
# Anagram

# %%
# remove special characters
s="Hello@123#World!"
result=""
for ch in s:
    if ch.isalnum():
        result+=ch
print(result)
# Out:
# Hello123World

# %%
# find most repeated character
s="programming"
max_char=""
max_count=0
for ch in s:
    if s.count(ch)> max_count:
        max_count=s.count(ch)
        max_cha=ch
print(max_char)

# %%
# capitalize first letter of every word
s="hello world python"
print(s.title())
# Out:
# Hello World Python

# %%
# find words starting with vowels
s="apple banana orange umbrella cat"
words=s.split()
for w in words:
    if w[0].lower() in "aeiou":
        print(w)
# Out:
# apple
# orange
# umbrella

# %%
# replace spaces with'_'
s="I Love Python"
print(s.replace(" ","-"))
# Out:
# I-Love-Python

# %%
# count vowels
s="Hello World"
for v in "aeiou":
    print(v,":",s.lower().count(v))
# Out:
# a : 0
# e : 1
# i : 0
# o : 2
# u : 0

# %%
# reverse string without slicing
s="Python"
rev=""
for ch in s:
    rev=ch+rev
print(rev)
# Out:
# nohtyP

# %%
# check palindrome
s="madam"
if s==s[::-1]:
    print("Palindrome")
else:
    print("Not Palindrome")
# Out:
# Palindrome

# %%
# count uppercase and lowercase letters
s="PyThOn"
upper=0
lower=0
for ch in s:
    if ch.isupper():
        upper+=1
    elif ch.islower():
        lower+=1
print("Uppercase=",upper)
print("Lowercase=",lower)
# Out:
# Uppercase= 3
# Lowercase= 3

# %%
# remove duplicate characters
s="Programming"
result=""
for ch in s:
    if ch not in result:
        result+=ch
print(result)
# Out:
# Progamin

# %%
# find first non-repeating character
s="aabbcdde"
for ch in s:
    if s.count(ch)==1:
        print(ch)
        break
# Out:
# c

# %%
tuple1=(1,2,3,4,4,5,5,6,6,[1,2,3,4,])
tuple1[-1][-1]

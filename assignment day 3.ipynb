# %%
# take your name as input and print it
name=input("Enter your name")
print(name)
# Out:
# Enter your name Pallavi
# Pallavi

# %%
# take two numbers from user and print their sum
a=int(input("Enter your first number"))
b=int(input("Enter your second number"))
print("sum=",a+b)
# Out:
# Enter your first number 3
# Enter your second number 4
# sum= 7

# %%
# take age as input and print it after converting to integer
age=int(input("Enter your age"))
print("age=",age)
# Out:
# Enter your age 18
# age= 18

# %%
# convert a float number into integer
num=9.23
print(int(num))
# Out:
# 9

# %%
# take two a number as input and print its data type
num=int(input("Enter your number"))
print(type(num))
# Out:
# Enter your number 78
# <class 'int'>

# %%
# take two numbers as inpur and print their multiplication
a=int(input("Enter your first number"))
b=int(input("Enter your second number"))
print("mul=",a*b)
# Out:
# Enter your first number 10
# Enter your second number 20
# mul= 200

# %%
# take a string and print it in uppercase
text=(input("Enter text"))
print("text".upper())
# Out:
# Enter text hello
# TEXT

# %%
# take marks as input and print it as float
marks=float(input("Enter your marks"))
print(marks)
# Out:
# Enter your marks 88
# 88.0

# %%
# take input of length and breadtha and print area of rectangle
length=float(input("Enter your length"))
breath=float(input("Enter your breath"))
area=length*breath
print("Area of rectangle=",area)
# Out:
# Enter your length 8
# Enter your breath 9
# Area of rectangle= 72.0
